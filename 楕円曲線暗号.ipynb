# %% [markdown]
# # 台数から学ぶ暗号理論の楕円曲線暗号（第１０章）についてのメモ

# %% [markdown]
# * 問題10.3
# E/F23の楕円曲線を用いて、楕円ElGamal暗号を実現せよ
#
# E/F23:y^2=x^3+x+1

# %%
# 問題10.3
(*'-')<
mod_23_list = []
for x in range(23):
    for y in range(23):
        if (x**3+x+1)%23 == pow(y, 2, 23):
            mod_23_list.append([x,y])

            
            
print(mod_23_list)
# Out:
# [[0, 1], [0, 22], [1, 7], [1, 16], [3, 10], [3, 13], [4, 0], [5, 4], [5, 19], [6, 4], [6, 19], [7, 11], [7, 12], [9, 7], [9, 16], [11, 3], [11, 20], [12, 4], [12, 19], [13, 7], [13, 16], [17, 3], [17, 20], [18, 3], [18, 20], [19, 5], [19, 18]]

# %%
# 80x+128m

for i in range()
